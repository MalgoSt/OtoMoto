# %% [markdown]
# # OTOMOTO.pl - WebSrapping
# <b>Małgorzata Stolarska</b><br>
# malgorzata.stolarska@gmail.com
#
# Purpose: obtaining data from www.OtoMoto.pl to analyze car offers. A wide range of data is collected.
#
# For performance reasons, the script is run on Google Colab and the data is saved in stages to Google Drive in case the session is broken.

# %% [markdown]
# ## Imports, setting parameters and options

# %%
# Set True for quick test, set False for full web scrapping
TEST_MODE = True

# %%
# Set Google Drive path 
from google.colab import drive
drive.mount('/content/gdrive')

# Path for saving data
path = "/".join(["/content/gdrive/MyDrive/ForColab/OtoMoto", ("Test" if TEST_MODE else "")])
path
# Out:
# Mounted at /content/gdrive
# '/content/gdrive/MyDrive/ForColab/OtoMoto/Test'

# %%
# Install chromium, its driver and selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 25 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (87.0.4280.66-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Requirement already satisfied: selenium in /usr/local/lib/python3.6/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)

# %%
# Other imports
import requests
import json
import time
import pickle
import pandas as pd
import numpy as np
from tqdm import tqdm # progress bar
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from requests.exceptions import TooManyRedirects

# Set options for driver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Pandas options 
pd.set_option('display.max_columns', None) 

# Parameters
PAUSE_TIME = 0.1              # for downloading page  
ACCEPT_BUTTON_PAUSE_TIME = 1  # for showing GDPR clause 
NUMBER_OF_TRIES = 20          # for accepting GDPR clause

# %%
link = r"https://www.otomoto.pl/osobowe" # the main website
ajax_link = r"https://www.otomoto.pl/ajax/jsdata/params/" # car brands

# %% [markdown]
# ## Gathering links to offers

# %%
def gather_hrefs(link, options=None, max_pages=None):
    
    """
    It collects links to offerts, where variable 'link' is a starting address.
    Because the webpage presents max. 500 pages, the method allows to collect max 16.000 offers:
    - if variable 'link' = https://www.otomoto.pl/osobowe", it returns offers of various brands,
    - if variable 'link' = https://www.otomoto.pl/osobowe/jeep", it returns offers of a given brand.
    """
    
    print("Starting page: %s" % link)
    
    # Launch driver
    driver = webdriver.Chrome(options=options)
    driver.get(link)
    time.sleep(ACCEPT_BUTTON_PAUSE_TIME)

    # Accept the clause (the Accept button is shown with delay)
    for i in range(NUMBER_OF_TRIES):
        try:
            button = driver.find_element_by_id('onetrust-accept-btn-handler')
            print("Progress... GDPR clause was accepted")
            button.click()
            time.sleep(PAUSE_TIME)
            break
        except NoSuchElementException as exception:
            time.sleep(PAUSE_TIME)
            continue
    
    hrefs = np.empty(0, dtype=str)
    page = 1

    while True:
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        articles = soup.find_all("article")
        for a in articles:
            if a.has_attr("data-href"):
                hrefs = np.append(hrefs, a["data-href"])
        
        # Progress
        if (max_pages is not None and page < 10) or (page % 20 == 0):
            print("Progress... Page: %i, number of hrefs: %i" % (page, len(hrefs)))

        # Next page
        try:
            button = driver.find_element_by_xpath(r'//span[@class="icon-arrow_right"]') 
            # Click button by java script, also if it's hidden:
            driver.execute_script("arguments[0].click();", button) 
            time.sleep(PAUSE_TIME)                                 
        except NoSuchElementException:
            print("Number of hrefs: %i" % len(hrefs))
            break              

        page += 1
        if max_pages is not None and page > max_pages: 
            break
            
    driver.close()    
    return hrefs

# %%
# Brands of cars
params = requests.get(ajax_link)
params = json.loads(params.text.split('var searchConditions = ')[1].split(';var searchConditionsAdding')[0])
car_brands = [p for p in params['values']['573']['571']]

# The word "warszawa" indicates a city, not a brand
if "warszawa" in set(car_brands):    
    car_brands[car_brands.index("warszawa")] = "marka_warszawa"
# The link with "other" does not work properly
if "other" in set(car_brands):    
    car_brands[car_brands.index("other")] = "inny"

print("Total number of brands: %i" % len(car_brands))

# Dump brands to pickle
with open("/".join([path, "car_brands.obj"]), "wb") as fp:
    pickle.dump(car_brands, fp)
# Out:
# Total number of brands: 111

# %%
# OR:
# Read data from pickle 
with open("/".join([path, "car_brands.obj"]), 'rb') as fp:
    car_brands = pickle.load(fp)

# %%
{i: b for i, b in enumerate(car_brands)}
# Out:
# {0: 'abarth',
#  1: 'acura',
#  2: 'aixam',
#  3: 'alfa-romeo',
#  4: 'alpine',
#  5: 'aston-martin',
#  6: 'audi',
#  7: 'austin',
#  8: 'autobianchi',
#  9: 'bac',
#  10: 'bentley',
#  11: 'bmw',
#  12: 'bollore',
#  13: 'brilliance',
#  14: 'buick',
#  15: 'cadillac',
#  16: 'casalini',
#  17: 'chatenet',
#  18: 'chevrolet',
#  19: 'chrysler',
#  20: 'citroen',
#  21: 'cupra',
#  22: 'dacia',
#  23: 'daewoo',
#  24: 'daihatsu',
#  25: 'de-lorean',
#  26: 'dfsk',
#  27: 'dkw',
#  28: 'dodge',
#  29: 'ds-automobiles',
#  30: 'faw',
#  31: 'ferrari',
#  32: 'fiat',
#  33: 'ford',
#  34: 'gaz',
#  35: 'gmc',
#  36: 'grecav',
#  37: 'holden',
#  38: 'honda',
#  39: 'hummer',
#  40: 'hyundai',
#  41: 'infiniti',
#  42: 'isuzu',
#  43: 'iveco',
#  44: 'jaguar',
#  45: 'jeep',
#  46: 'kia',
#  47: 'lada',
#  48: 'lamborghini',
#  49: 'lancia',
#  50: 'land-rover',
#  51: 'lexus',
#  52: 'ligier',
#  53: 'lincoln',
#  54: 'lotus',
#  55: 'maserati',
#  56: 'maybach',
#  57: 'mazda',
#  58: 'mclaren',
#  59: 'mercedes-benz',
#  60: 'mercury',
#  61: 'mg',
#  62: 'microcar',
#  63: 'mini',
#  64: 'mitsubishi',
#  65: 'moskwicz',
#  66: 'nissan',
#  67: 'nysa',
#  68: 'oldsmobile',
#  69: 'opel',
#  70: 'inny',
#  71: 'peugeot',
#  72: 'piaggio',
#  73: 'plymouth',
#  74: 'polonez',
#  75: 'pontiac',
#  76: 'porsche',
#  77: 'radical',
#  78: 'ram',
#  79: 'renault',
#  80: 'rolls-royce',
#  81: 'rover',
#  82: 'saab',
#  83: 'scion',
#  84: 'seat',
#  85: 'shuanghuan',
#  86: 'skoda',
#  87: 'smart',
#  88: 'ssangyong',
#  89: 'subaru',
#  90: 'suzuki',
#  91: 'syrena',
#  92: 'talbot',
#  93: 'tarpan',
#  94: 'tata',
#  95: 'tavria',
#  96: 'tesla',
#  97: 'toyota',
#  98: 'trabant',
#  99: 'triumph',
#  100: 'uaz',
#  101: 'vanderhall',
#  102: 'vauxhall',
#  103: 'volkswagen',
#  104: 'volvo',
#  105: 'marka_warszawa',
#  106: 'wartburg',
#  107: 'wolga',
#  108: 'zaporozec',
#  109: 'zastawa',
#  110: 'zuk'}

# %%
# ----------------------------------------------
# Only the first three brands in test mode
if TEST_MODE:
    car_brands = car_brands[0:3]
#-----------------------------------------------

# %%
# Search brand by brand
start = 0  # change to continue the broken loop
for brand in car_brands[start:]:      
    hrefs = gather_hrefs("/".join([link, brand]), options, max_pages=None)

    # Remove duplicates if exist
    hrefs = list(set(hrefs))
    
    # Dump hrefs to pickle
    with open("".join([path, "/hrefs_", brand, ".obj"]), "wb") as fp:
        pickle.dump(hrefs, fp)  

    print("-" * 30)
# Out:
# Starting page: https://www.otomoto.pl/osobowe/abarth
# Progress... GDPR clause was accepted
# Number of hrefs: 42
# ------------------------------
# Starting page: https://www.otomoto.pl/osobowe/acura
# Progress... GDPR clause was accepted
# Number of hrefs: 15
# ------------------------------
# Starting page: https://www.otomoto.pl/osobowe/aixam
# Progress... GDPR clause was accepted
# Number of hrefs: 102
# ------------------------------

# %% [markdown]
# ## Obtaining data from offers

# %%
def gather_offerts(hrefs, with_description=False):

    """
    It collects the data of a single offer, located at the link 'href'.
    Collected data:
    - price details,
    - seller details,
    - car parameters,
    - additional features,
    - id, link and description (optional, if with description=True).
    If id is not founs
    """

    df = pd.DataFrame()
    col = ["href", "price_evaluation","price","currency","price_details","seller_type","seller_name"]
    if with_description:
        df_desc = pd.DataFrame() 
    else:
        df_desc = None   

    page = 0 
    total = len(hrefs)

    for href in hrefs:
        try:
          www = requests.get(href)
        except TooManyRedirects as exception:
            print("TooManyRedirects for href: %s" % href)
            continue  
            
        soup = BeautifulSoup(www.text, 'html.parser')

        # ID of article
        ad_id = soup.find("span", id="ad_id", class_="offer-meta__value")
        if ad_id is None: 
            continue # if the offer is removed, go to the next offer
        else:
            ad_id = ad_id.get_text().strip()     

        # Price is below/above/in average
        price_evaluation = soup.find("div", {"data-widget" : "PriceEvaluation/Display"})
        price_evaluation = json.loads(price_evaluation.get("data-props"))["indicator"] \
                                      if price_evaluation is not None else np.NaN

        price = soup.find("span", class_="offer-price__number").next_element
        currency = soup.find("span", class_="offer-price__currency")
        price_details = soup.find("span", class_="offer-price__details")
        seller_type = soup.find("small", class_="seller-box__seller-type")
        seller_name = soup.find("h2", class_="seller-box__seller-name")      

        val = [href]
        val.append(price_evaluation)
        val.append(price.strip() if price is not None else np.NaN)
        val.append(currency.get_text().strip() if currency is not None else np.NaN)
        val.append(price_details.get_text().strip() if price_details is not None else np.NaN)
        val.append(seller_type.get_text().strip() if seller_type is not None else np.NaN)
        val.append(seller_name.get_text().strip() if seller_name is not None else np.NaN)   

        # The parameter sets differ for offers
        parm_col = [p.get_text().strip() for p in soup.findAll("span", class_="offer-params__label")]
        parm_val = [p.get_text().strip() for p in soup.findAll("div", class_="offer-params__value")]

        # The features sets differ for offers
        feat_col = [p.get_text().strip() for p in soup.findAll("li", class_="offer-features__item")]
        feat_val = [1 for p in feat_col]
        
        # Remove duplicated columns (duplicated columns are the result of an error on the page)
        columns = col + parm_col + feat_col
        new_df = pd.DataFrame([val + parm_val + feat_val], columns=columns)
        duplicates = [i for i in columns if columns.count(i)>1]
        if len(duplicates) > 0:
            new_df = new_df.drop(columns=duplicates)      

        # Append new row to df
        try:
            df = df.append(new_df, ignore_index=True)         
        except ValueError as exception:
            print("ValueError [%s] for href: %s" % (str(exception), href))
            continue        

        if with_description:
            description = soup.find("div", class_="offer-description__description").get_text().strip()
            df_desc = df_desc.append(pd.Series([ad_id, description, href]),
                                     ignore_index=True)
        
        page += 1
        if page % 50 == 0:
            print("Progress... Page: %i / %i" % (page, total))

    if with_description:
        df_desc.columns = ["ad_id", "description", "href"]
    
    return df, df_desc

# %%
# Brand by brand
start = 0  # change to continue the broken loop
for brand in car_brands[start:]:    

    # Load hrefs from dump
    with open("".join([path, "/hrefs_", brand, ".obj"]), 'rb') as fp:
        hrefs = pickle.load(fp)

    print("Brand: %s, number of hrefs: %i" % (brand, len(hrefs)))
    offers, desc = gather_offerts(hrefs, with_description=False)
    
    # Dump offers to pickle
    with open("".join([path, "/offers_", brand, ".obj"]), "wb") as fp:
        pickle.dump(offers, fp)  
  
    # Dump desc to pickle
    if desc is not None:
        with open("".join([path, "/desc_", brand, ".obj"]), "wb") as fp:
            pickle.dump(desc, fp)     
 
    print("Brand: %s, number of offers downloaded: %i" % (brand, len(offers)))
# Out:
# Brand: abarth, number of hrefs: 42
# Brand: abarth, number of offers downloaded: 42
# Brand: acura, number of hrefs: 15
# Brand: acura, number of offers downloaded: 15
# Brand: aixam, number of hrefs: 102
# Progress... Page: 50 / 102
# Progress... Page: 100 / 102
# Brand: aixam, number of offers downloaded: 102

# %% [markdown]
# ## Summary and rewriting offerts to one file

# %%
total_number_hrefs = 0
total_number_offers = 0
total_number_desc = 0
offers = pd.DataFrame()

for brand in car_brands:    

    # Load data from dumps
    h, o, d = [], [], []
    try:
        with open("".join([path, "/hrefs_", brand, ".obj"]), 'rb') as fp:
            h = pickle.load(fp)
        with open("".join([path, "/offers_", brand, ".obj"]), 'rb') as fp:
            o = pickle.load(fp)
        with open("".join([path, "/desc_", brand, ".obj"]), 'rb') as fp:
            d = pickle.load(fp)
    except FileNotFoundError as ex:
        pass

    offers = offers.append(o, ignore_index=True)

    print ("{:<15} index:{:>3} | HREFS:{:>6} | OFFERS:{:>6} | STATUS:{:>5} | DESC:{:>6}"\
           .format(brand, car_brands.index(brand), len(h), len(o), \
                  ("OK" if len(o) > 0 else "None"), (len(d) if d is not None else 0)))
    total_number_hrefs += len(h)
    total_number_offers += len(o) 
    total_number_desc += len(d)

# Differences between number of hrefs and offers are natural
# (some offers have been removed in the meantime)
print("{:<26}| HREFS:{:>6} | OFFERS:{:>6} | RATIO:{:>6} | DESC:{:>6}"\
      .format("TOTAL NUMBER:", total_number_hrefs, total_number_offers, \
              round(total_number_offers/total_number_hrefs,1), total_number_desc))
# Out:
# abarth          index:  0 | HREFS:    41 | OFFERS:    40 | STATUS:   OK | DESC:     0
# acura           index:  1 | HREFS:    15 | OFFERS:    15 | STATUS:   OK | DESC:     0
# aixam           index:  2 | HREFS:   103 | OFFERS:   103 | STATUS:   OK | DESC:     0
# alfa-romeo      index:  3 | HREFS:  1328 | OFFERS:  1311 | STATUS:   OK | DESC:     0
# alpine          index:  4 | HREFS:     6 | OFFERS:     6 | STATUS:   OK | DESC:     0
# aston-martin    index:  5 | HREFS:    18 | OFFERS:    18 | STATUS:   OK | DESC:     0
# audi            index:  6 | HREFS: 14872 | OFFERS: 14399 | STATUS:   OK | DESC:     0
# austin          index:  7 | HREFS:     4 | OFFERS:     4 | STATUS:   OK | DESC:     0
# autobianchi     index:  8 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# bac             index:  9 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# bentley         index: 10 | HREFS:    63 | OFFERS:    60 | STATUS:   OK | DESC:     0
# bmw             index: 11 | HREFS: 15879 | OFFERS: 15349 | STATUS:   OK | DESC:     0
# bollore         index: 12 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# brilliance      index: 13 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# buick           index: 14 | HREFS:    20 | OFFERS:    19 | STATUS:   OK | DESC:     0
# cadillac        index: 15 | HREFS:   110 | OFFERS:   109 | STATUS:   OK | DESC:     0
# casalini        index: 16 | HREFS:     5 | OFFERS:     5 | STATUS:   OK | DESC:     0
# chatenet        index: 17 | HREFS:     7 | OFFERS:     7 | STATUS:   OK | DESC:     0
# chevrolet       index: 18 | HREFS:  1514 | OFFERS:  1450 | STATUS:   OK | DESC:     0
# chrysler        index: 19 | HREFS:   671 | OFFERS:   648 | STATUS:   OK | DESC:     0
# citroen         index: 20 | HREFS:  7046 | OFFERS:  6779 | STATUS:   OK | DESC:     0
# cupra           index: 21 | HREFS:   170 | OFFERS:   169 | STATUS:   OK | DESC:     0
# dacia           index: 22 | HREFS:  1840 | OFFERS:  1764 | STATUS:   OK | DESC:     0
# daewoo          index: 23 | HREFS:   100 | OFFERS:    93 | STATUS:   OK | DESC:     0
# daihatsu        index: 24 | HREFS:   132 | OFFERS:   123 | STATUS:   OK | DESC:     0
# de-lorean       index: 25 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# dfsk            index: 26 | HREFS:     5 | OFFERS:     5 | STATUS:   OK | DESC:     0
# dkw             index: 27 | HREFS:     3 | OFFERS:     3 | STATUS:   OK | DESC:     0
# dodge           index: 28 | HREFS:   657 | OFFERS:   636 | STATUS:   OK | DESC:     0
# ds-automobiles  index: 29 | HREFS:   121 | OFFERS:   120 | STATUS:   OK | DESC:     0
# faw             index: 30 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# ferrari         index: 31 | HREFS:    54 | OFFERS:    54 | STATUS:   OK | DESC:     0
# fiat            index: 32 | HREFS:  4576 | OFFERS:  4389 | STATUS:   OK | DESC:     0
# ford            index: 33 | HREFS: 15598 | OFFERS: 14881 | STATUS:   OK | DESC:     0
# gaz             index: 34 | HREFS:     4 | OFFERS:     4 | STATUS:   OK | DESC:     0
# gmc             index: 35 | HREFS:    16 | OFFERS:    16 | STATUS:   OK | DESC:     0
# grecav          index: 36 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# holden          index: 37 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# honda           index: 38 | HREFS:  4111 | OFFERS:  3935 | STATUS:   OK | DESC:     0
# hummer          index: 39 | HREFS:    26 | OFFERS:    23 | STATUS:   OK | DESC:     0
# hyundai         index: 40 | HREFS:  5935 | OFFERS:  5614 | STATUS:   OK | DESC:     0
# infiniti        index: 41 | HREFS:   252 | OFFERS:   241 | STATUS:   OK | DESC:     0
# isuzu           index: 42 | HREFS:    60 | OFFERS:    59 | STATUS:   OK | DESC:     0
# iveco           index: 43 | HREFS:     4 | OFFERS:     3 | STATUS:   OK | DESC:     0
# jaguar          index: 44 | HREFS:   910 | OFFERS:   871 | STATUS:   OK | DESC:     0
# jeep            index: 45 | HREFS:  1597 | OFFERS:  1519 | STATUS:   OK | DESC:     0
# kia             index: 46 | HREFS:  5846 | OFFERS:  5499 | STATUS:   OK | DESC:     0
# lada            index: 47 | HREFS:    22 | OFFERS:    22 | STATUS:   OK | DESC:     0
# lamborghini     index: 48 | HREFS:    27 | OFFERS:    27 | STATUS:   OK | DESC:     0
# lancia          index: 49 | HREFS:   214 | OFFERS:   209 | STATUS:   OK | DESC:     0
# land-rover      index: 50 | HREFS:  1111 | OFFERS:  1075 | STATUS:   OK | DESC:     0
# lexus           index: 51 | HREFS:  1058 | OFFERS:  1028 | STATUS:   OK | DESC:     0
# ligier          index: 52 | HREFS:    25 | OFFERS:    24 | STATUS:   OK | DESC:     0
# lincoln         index: 53 | HREFS:    49 | OFFERS:    49 | STATUS:   OK | DESC:     0
# lotus           index: 54 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# maserati        index: 55 | HREFS:   173 | OFFERS:   170 | STATUS:   OK | DESC:     0
# maybach         index: 56 | HREFS:     5 | OFFERS:     5 | STATUS:   OK | DESC:     0
# mazda           index: 57 | HREFS:  4426 | OFFERS:  4241 | STATUS:   OK | DESC:     0
# mclaren         index: 58 | HREFS:    30 | OFFERS:    29 | STATUS:   OK | DESC:     0
# mercedes-benz   index: 59 | HREFS: 11413 | OFFERS: 10904 | STATUS:   OK | DESC:     0
# mercury         index: 60 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# mg              index: 61 | HREFS:    14 | OFFERS:    14 | STATUS:   OK | DESC:     0
# microcar        index: 62 | HREFS:    52 | OFFERS:    50 | STATUS:   OK | DESC:     0
# mini            index: 63 | HREFS:  1422 | OFFERS:  1388 | STATUS:   OK | DESC:     0
# mitsubishi      index: 64 | HREFS:  2056 | OFFERS:  1973 | STATUS:   OK | DESC:     0
# moskwicz        index: 65 | HREFS:     6 | OFFERS:     6 | STATUS:   OK | DESC:     0
# nissan          index: 66 | HREFS:  4953 | OFFERS:  4761 | STATUS:   OK | DESC:     0
# nysa            index: 67 | HREFS:     3 | OFFERS:     2 | STATUS:   OK | DESC:     0
# oldsmobile      index: 68 | HREFS:     9 | OFFERS:     9 | STATUS:   OK | DESC:     0
# opel            index: 69 | HREFS: 15993 | OFFERS: 15455 | STATUS:   OK | DESC:     0
# inny            index: 70 | HREFS:    59 | OFFERS:    58 | STATUS:   OK | DESC:     0
# peugeot         index: 71 | HREFS:  8263 | OFFERS:  7837 | STATUS:   OK | DESC:     0
# plymouth        index: 72 | HREFS:     7 | OFFERS:     7 | STATUS:   OK | DESC:     0
# polonez         index: 73 | HREFS:    42 | OFFERS:    41 | STATUS:   OK | DESC:     0
# pontiac         index: 74 | HREFS:    16 | OFFERS:    16 | STATUS:   OK | DESC:     0
# porsche         index: 75 | HREFS:  1123 | OFFERS:  1096 | STATUS:   OK | DESC:     0
# radical         index: 76 | HREFS:     2 | OFFERS:     2 | STATUS:   OK | DESC:     0
# ram             index: 77 | HREFS:    57 | OFFERS:    57 | STATUS:   OK | DESC:     0
# renault         index: 78 | HREFS: 10500 | OFFERS: 10159 | STATUS:   OK | DESC:     0
# rolls-royce     index: 79 | HREFS:    26 | OFFERS:    26 | STATUS:   OK | DESC:     0
# rover           index: 80 | HREFS:    38 | OFFERS:    37 | STATUS:   OK | DESC:     0
# saab            index: 81 | HREFS:   395 | OFFERS:   386 | STATUS:   OK | DESC:     0
# scion           index: 82 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# seat            index: 83 | HREFS:  4862 | OFFERS:  4754 | STATUS:   OK | DESC:     0
# shuanghuan      index: 84 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# skoda           index: 85 | HREFS: 10311 | OFFERS: 10039 | STATUS:   OK | DESC:     0
# smart           index: 86 | HREFS:   247 | OFFERS:   245 | STATUS:   OK | DESC:     0
# ssangyong       index: 87 | HREFS:   160 | OFFERS:   159 | STATUS:   OK | DESC:     0
# subaru          index: 88 | HREFS:   895 | OFFERS:   891 | STATUS:   OK | DESC:     0
# suzuki          index: 89 | HREFS:  2542 | OFFERS:  2511 | STATUS:   OK | DESC:     0
# syrena          index: 90 | HREFS:    10 | OFFERS:    10 | STATUS:   OK | DESC:     0
# talbot          index: 91 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# tarpan          index: 92 | HREFS:     4 | OFFERS:     4 | STATUS:   OK | DESC:     0
# tata            index: 93 | HREFS:    11 | OFFERS:    11 | STATUS:   OK | DESC:     0
# tavria          index: 94 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# tesla           index: 95 | HREFS:    79 | OFFERS:    79 | STATUS:   OK | DESC:     0
# toyota          index: 96 | HREFS: 10473 | OFFERS: 10285 | STATUS:   OK | DESC:     0
# trabant         index: 97 | HREFS:    13 | OFFERS:    12 | STATUS:   OK | DESC:     0
# triumph         index: 98 | HREFS:     5 | OFFERS:     5 | STATUS:   OK | DESC:     0
# uaz             index: 99 | HREFS:     7 | OFFERS:     7 | STATUS:   OK | DESC:     0
# vanderhall      index:100 | HREFS:     1 | OFFERS:     1 | STATUS:   OK | DESC:     0
# vauxhall        index:101 | HREFS:     4 | OFFERS:     4 | STATUS:   OK | DESC:     0
# volkswagen      index:102 | HREFS: 15949 | OFFERS: 15734 | STATUS:   OK | DESC:     0
# volvo           index:103 | HREFS:  5677 | OFFERS:  5557 | STATUS:   OK | DESC:     0
# marka_warszawa  index:104 | HREFS:    11 | OFFERS:    10 | STATUS:   OK | DESC:     0
# wartburg        index:105 | HREFS:     6 | OFFERS:     6 | STATUS:   OK | DESC:     0
# wolga           index:106 | HREFS:     8 | OFFERS:     7 | STATUS:   OK | DESC:     0
# zaporozec       index:107 | HREFS:     4 | OFFERS:     4 | STATUS:   OK | DESC:     0
# zastawa         index:108 | HREFS:     3 | OFFERS:     3 | STATUS:   OK | DESC:     0
# zuk             index:109 | HREFS:     3 | OFFERS:     3 | STATUS:   OK | DESC:     0
# TOTAL NUMBER:             | HREFS:198612 | OFFERS:191866 | RATIO:   1.0 | DESC:     0

# %%
offers.shape
# Out:
# (191866, 128)

# %%
offers.head()
# Out:
#                                                 href price_evaluation  \
# 0  https://www.otomoto.pl/oferta/abarth-595-pista...            above
# 1  https://www.otomoto.pl/oferta/abarth-695-1-4-1...             none
# 2  https://www.otomoto.pl/oferta/abarth-595-abart...               in
# 3  https://www.otomoto.pl/oferta/abarth-595-500-1...            above
# 4  https://www.otomoto.pl/oferta/abarth-595-abart...             none
#
#      price currency               price_details          seller_type  \
# 0   79 999      PLN                 Faktura VAT       Osoba prywatna
# 1  110 000      PLN  Do negocjacji, Faktura VAT  Autoryzowany Dealer
# 2   63 500      PLN                 Faktura VAT       Osoba prywatna
# 3   36 900      PLN  Do negocjacji, Faktura VAT       Osoba prywatna
# 4   84 300      PLN                              Autoryzowany Dealer
#
#                                          seller_name        Oferta od  \
# 0                                              Paweł  Osoby prywatnej
# 1  Grupa Gezet Fiat, Abarth, Alfa Romeo, Jeep, Ho...            Firmy
# 2                                              Piotr  Osoby prywatnej
# 3                                             Patryk  Osoby prywatnej
# 4  Dukiewicz Sp Jawna Dealer Fiat Abarth Alfa Rom...            Firmy
#
#   Kategoria Marka pojazdu Model pojazdu Rok produkcji    Przebieg  \
# 0   Osobowe        Abarth           595          2018   12 150 km
# 1   Osobowe        Abarth           695          2020        5 km
# 2   Osobowe        Abarth           595          2017   39 000 km
# 3   Osobowe        Abarth           595          2009  209 606 km
# 4   Osobowe        Abarth           595          2020        1 km
#
#   Pojemność skokowa Rodzaj paliwa     Moc Skrzynia biegów             Napęd  \
# 0         1 400 cm3       Benzyna  160 KM        Manualna  Na przednie koła
# 1         1 368 cm3       Benzyna  180 KM        Manualna  Na przednie koła
# 2         1 400 cm3       Benzyna  145 KM        Manualna  Na przednie koła
# 3         1 400 cm3       Benzyna  190 KM        Manualna  Na przednie koła
# 4         1 368 cm3       Benzyna  145 KM        Manualna               NaN
#
#          Typ Liczba drzwi Liczba miejsc       Kolor Faktura VAT  \
# 0  Auta małe            2             4       Szary         Tak
# 1    Kompakt            3             4     Zielony         Tak
# 2  Auta małe            3             4       Biały         Tak
# 3  Auta małe            3             4  Inny kolor         Tak
# 4  Auta małe            3           NaN    Czerwony         NaN
#
#   Kraj pochodzenia Pierwsza rejestracja Numer rejestracyjny pojazdu  \
# 0           Polska           24/05/2019                     WX8359A
# 1           Polska                  NaN                         NaN
# 2           Polska           19/07/2017                         NaN
# 3              NaN           22/04/2009                    SO113473
# 4              NaN                  NaN                         NaN
#
#   Zarejestrowany w Polsce Pierwszy właściciel Bezwypadkowy Serwisowany w ASO  \
# 0                     Tak                 Tak          Tak               Tak
# 1                     NaN                 NaN          Tak               NaN
# 2                     Tak                 NaN          Tak               Tak
# 3                     NaN                 NaN          NaN               Tak
# 4                     NaN                 NaN          Tak               NaN
#
#       Stan Metalik Możliwość finansowania  ABS  Bluetooth  Czujnik zmierzchu  \
# 0  Używane     NaN                    NaN  NaN        NaN                NaN
# 1     Nowe     Tak                    Tak  1.0        1.0                1.0
# 2  Używane     NaN                    NaN  NaN        NaN                NaN
# 3  Używane     Tak                    NaN  1.0        1.0                NaN
# 4     Nowe     NaN                    NaN  NaN        NaN                NaN
#
#    Elektrycznie ustawiane lusterka  Gniazdo USB  Klimatyzacja automatyczna  \
# 0                              NaN          NaN                        NaN
# 1                              1.0          1.0                        1.0
# 2                              NaN          NaN                        NaN
# 3                              1.0          1.0                        1.0
# 4                              NaN          NaN                        NaN
#
#    MP3  Poduszka powietrzna chroniąca kolana  Poduszki boczne przednie  \
# 0  NaN                                   NaN                       NaN
# 1  1.0                                   1.0                       1.0
# 2  NaN                                   NaN                       NaN
# 3  1.0                                   1.0                       NaN
# 4  NaN                                   NaN                       NaN
#
#    Radio niefabryczne  Światła do jazdy dziennej  Szyberdach  Alufelgi  \
# 0                 NaN                        NaN         NaN       NaN
# 1                 1.0                        1.0         1.0       1.0
# 2                 NaN                        NaN         NaN       NaN
# 3                 1.0                        1.0         NaN       1.0
# 4                 NaN                        NaN         NaN       NaN
#
#    Centralny zamek  Czujniki parkowania tylne  ESP (stabilizacja toru jazdy)  \
# 0              NaN                        NaN                            NaN
# 1              1.0                        1.0                            1.0
# 2              NaN                        NaN                            NaN
# 3              1.0                        NaN                            NaN
# 4              NaN                        NaN                            NaN
#
#    Immobilizer  Komputer pokładowy  Ogranicznik prędkości  \
# 0          NaN                 NaN                    NaN
# 1          1.0                 1.0                    1.0
# 2          NaN                 NaN                    NaN
# 3          1.0                 1.0                    NaN
# 4          NaN                 NaN                    NaN
#
#    Poduszka powietrzna kierowcy  Poduszki boczne tylne  Radio fabryczne  \
# 0                           NaN                    NaN              NaN
# 1                           1.0                    1.0              1.0
# 2                           NaN                    NaN              NaN
# 3                           1.0                    NaN              NaN
# 4                           NaN                    NaN              NaN
#
#    Światła LED  Wielofunkcyjna kierownica  ASR (kontrola trakcji)  \
# 0          NaN                        NaN                     NaN
# 1          1.0                        1.0                     1.0
# 2          NaN                        NaN                     NaN
# 3          NaN                        1.0                     1.0
# 4          NaN                        NaN                     NaN
#
#    Czujnik deszczu  Elektryczne szyby przednie  Gniazdo AUX  Isofix  \
# 0              NaN                         NaN          NaN     NaN
# 1              1.0                         1.0          1.0     1.0
# 2              NaN                         NaN          NaN     NaN
# 3              NaN                         1.0          1.0     NaN
# 4              NaN                         NaN          NaN     NaN
#
#    Kurtyny powietrzne  Podgrzewane lusterka boczne  \
# 0                 NaN                          NaN
# 1                 1.0                          1.0
# 2                 NaN                          NaN
# 3                 1.0                          NaN
# 4                 NaN                          NaN
#
#    Poduszka powietrzna pasażera  Przyciemniane szyby  Światła Xenonowe  \
# 0                           NaN                  NaN               NaN
# 1                           1.0                  1.0               1.0
# 2                           NaN                  NaN               NaN
# 3                           1.0                  1.0               NaN
# 4                           NaN                  NaN               NaN
#
#    Światła przeciwmgielne  Wspomaganie kierownicy Emisja CO2  \
# 0                     NaN                     NaN        NaN
# 1                     1.0                     1.0        NaN
# 2                     NaN                     NaN   154 g/km
# 3                     1.0                     1.0   155 g/km
# 4                     NaN                     NaN        NaN
#
#   Okres gwarancji producenta Perłowy Tuning  Alarm   CD  Tapicerka welurowa  \
# 0                        NaN     NaN    NaN    NaN  NaN                 NaN
# 1                        NaN     NaN    NaN    NaN  NaN                 NaN
# 2                 17/07/2021     NaN    NaN    NaN  NaN                 NaN
# 3                        NaN     Tak    Tak    1.0  1.0                 1.0
# 4                        NaN     NaN    NaN    NaN  NaN                 NaN
#
#    Gniazdo SD  Tempomat  Dach panoramiczny  Podgrzewana przednia szyba  \
# 0         NaN       NaN                NaN                         NaN
# 1         NaN       NaN                NaN                         NaN
# 2         NaN       NaN                NaN                         NaN
# 3         1.0       1.0                NaN                         NaN
# 4         NaN       NaN                NaN                         NaN
#
#    Klimatyzacja manualna  System Start-Stop Leasing Opłata początkowa  \
# 0                    NaN                NaN     NaN               NaN
# 1                    NaN                NaN     NaN               NaN
# 2                    NaN                NaN     NaN               NaN
# 3                    NaN                NaN     NaN               NaN
# 4                    NaN                NaN     NaN               NaN
#
#   Miesięczna rata Liczba pozostałych rat Wartość wykupu Matowy  \
# 0             NaN                    NaN            NaN    NaN
# 1             NaN                    NaN            NaN    NaN
# 2             NaN                    NaN            NaN    NaN
# 3             NaN                    NaN            NaN    NaN
# 4             NaN                    NaN            NaN    NaN
#
#   Akryl (niemetalizowany) VAT marża  Asystent parkowania  \
# 0                     NaN       NaN                  NaN
# 1                     NaN       NaN                  NaN
# 2                     NaN       NaN                  NaN
# 3                     NaN       NaN                  NaN
# 4                     NaN       NaN                  NaN
#
#    Klimatyzacja dwustrefowa  Regulowane zawieszenie  Nawigacja GPS  \
# 0                       NaN                     NaN            NaN
# 1                       NaN                     NaN            NaN
# 2                       NaN                     NaN            NaN
# 3                       NaN                     NaN            NaN
# 4                       NaN                     NaN            NaN
#
#    Tapicerka skórzana  Elektrochromatyczne lusterko wsteczne Uszkodzony  \
# 0                 NaN                                    NaN        NaN
# 1                 NaN                                    NaN        NaN
# 2                 NaN                                    NaN        NaN
# 3                 NaN                                    NaN        NaN
# 4                 NaN                                    NaN        NaN
#
#    Czujniki parkowania przednie  Kamera cofania  Odtwarzacz DVD  \
# 0                           NaN             NaN             NaN
# 1                           NaN             NaN             NaN
# 2                           NaN             NaN             NaN
# 3                           NaN             NaN             NaN
# 4                           NaN             NaN             NaN
#
#    Podgrzewane przednie siedzenia  Elektrochromatyczne lusterka boczne  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
#
#    Tuner TV Wersja  Łopatki zmiany biegów  Elektryczne szyby tylne  \
# 0       NaN    NaN                    NaN                      NaN
# 1       NaN    NaN                    NaN                      NaN
# 2       NaN    NaN                    NaN                      NaN
# 3       NaN    NaN                    NaN                      NaN
# 4       NaN    NaN                    NaN                      NaN
#
#   lub do (przebieg km)  Elektrycznie ustawiane fotele  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
#    Klimatyzacja czterostrefowa  Asystent pasa ruchu  Czujnik martwego pola  \
# 0                          NaN                  NaN                    NaN
# 1                          NaN                  NaN                    NaN
# 2                          NaN                  NaN                    NaN
# 3                          NaN                  NaN                    NaN
# 4                          NaN                  NaN                    NaN
#
#    Zmieniarka CD  Relingi dachowe  Hak  Tempomat aktywny  \
# 0            NaN              NaN  NaN               NaN
# 1            NaN              NaN  NaN               NaN
# 2            NaN              NaN  NaN               NaN
# 3            NaN              NaN  NaN               NaN
# 4            NaN              NaN  NaN               NaN
#
#    Podgrzewane tylne siedzenia Kierownica po prawej (Anglik)  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   Gwarancja dealerska (w cenie)  Ogrzewanie postojowe Filtr cząstek stałych  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                           NaN                   NaN                   NaN
# 3                           NaN                   NaN                   NaN
# 4                           NaN                   NaN                   NaN
#
#   Generacja  HUD (wyświetlacz przezierny)  VIN Homologacja ciężarowa  \
# 0       NaN                           NaN  NaN                   NaN
# 1       NaN                           NaN  NaN                   NaN
# 2       NaN                           NaN  NaN                   NaN
# 3       NaN                           NaN  NaN                   NaN
# 4       NaN                           NaN  NaN                   NaN
#
#   Zarejestrowany jako zabytek Warranty if agreed with the buyer Kod Silnika  \
# 0                         NaN                               NaN         NaN
# 1                         NaN                               NaN         NaN
# 2                         NaN                               NaN         NaN
# 3                         NaN                               NaN         NaN
# 4                         NaN                               NaN         NaN
#
#
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
# Dump all offers to pickle
with open("".join([path, "/offers.obj"]), "wb") as fp:
    pickle.dump(offers, fp)

# %%
# Write offers to CSV
offers.to_csv("/".join([path, "offers.csv"]), encoding="UTF-8")    
 
# For reading:
# pd.read_csv("/".join([path, "offers.csv"]), encoding="UTF-8")
